# %% [markdown]
# Get your own API key and Access Token from Twitter: https://www.gabfirethemes.com/create-twitter-api-key/

# %%
api_key = 'GVnHQ6rkd1UGQKY9xSX9NupCD'
api_secret = 'zzhTxznO8EKGaD2hQSo4H4ZPFwkkPfFzR8HUlVtVNBQOaQw6bp'
access_token = '213419166-H5v2hA21Ygkp5RNfFjDVXFl5NElOVfNsL4J92VHH'
access_token_secret = 'QSFm0eWvsUb8sdsZvnnMewc7wWhk7SSvg4YLlIOprRV6v'

# %%
import tweepy

# %%
auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
users = api.search_users(q='USA')

# %%
len(users)
# Out:
# 20

# %%
print('We found {} users'.format(len(users)))
for user in users:
    print(user.name)
# Out:
# We found 20 users
# Donald J. Trump
# CNN
# USA TODAY
# Dept. of Agriculture
# Nancy Pelosi
# GOP
# Big Brother
# Department of State
# Library of Congress
# U.S. Dept of Defense
# Sec. Wilbur Ross
# T-Mobile
# Vice President Mike Pence
# Paul Ryan
# Energy Department
# U.S. Soccer MNT
# Treasury Department
# President Trump
# U.S. Soccer WNT
# U.S. Commerce Dept.

# %%
dir(users[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'contributors_enabled',
#  'created_at',
#  'default_profile',
#  'default_profile_image',
#  'description',
#  'entities',
#  'favourites_count',
#  'follow',
#  'follow_request_sent',
#  'followers',
#  'followers_count',
#  'followers_ids',
#  'following',
#  'friends',
#  'friends_count',
#  'geo_enabled',
#  'has_extended_profile',
#  'id',
#  'id_str',
#  'is_translation_enabled',
#  'is_translator',
#  'lang',
#  'listed_count',
#  'lists',
#  'lists_memberships',
#  'lists_subscriptions',
#  'location',
#  'name',
#  'notifications',
#  'parse',
#  'parse_list',
#  'profile_background_color',
#  'profile_background_image_url',
#  'profile_background_image_url_https',
#  'profile_background_tile',
#  'profile_banner_url',
#  'profile_image_url',
#  'profile_image_url_https',
#  'profile_link_color',
#  'profile_sidebar_border_color',
#  'profile_sidebar_fill_color',
#  'profile_text_color',
#  'profile_use_background_image',
#  'protected',
#  'screen_name',
#  'status',
#  'statuses_count',
#  'time_zone',
#  'timeline',
#  'translator_type',
#  'unfollow',
#  'url',
#  'utc_offset',
#  'verified']

# %%
trump = users[0]

# %%
trump.name
# Out:
# 'Donald J. Trump'

# %%
trump.screen_name
# Out:
# 'realDonaldTrump'

# %%
trump.followers_count / (1 * 10 ** 6)
# Out:
# 57.83848

# %%
trump_tweets = tweepy.Cursor(api.user_timeline, screen_name=trump.screen_name).items(50)

# %%
for tweet in trump_tweets:
    print(tweet.text)
# Out:
# How does Da Nang Dick (Blumenthal) serve on the Senate Judiciary Committee when he defrauded the American people ab… https://t.co/JBKLZ66qx6
# In the beautiful Midwest, windchill temperatures are reaching minus 60 degrees, the coldest ever recorded. In comin… https://t.co/FnaCaBA5Nz
# “In the Media’s effort to destroy the President, they are actually destroying themselves. Given all of the tremendo… https://t.co/yXteAEPz17
# 7  Never thought I’d say this but I think @johnro...
# 8  BUILD A WALL &amp; CRIME WILL FALL! https://t....
# 9  #HolocaustMemorialDay\nhttps://t.co/zBQjfUOdtj...

# %%
data.head(20)
# Out:
#                                                Tweets
# 0   How does Da Nang Dick (Blumenthal) serve on th...
# 1   In the beautiful Midwest, windchill temperatur...
# 2   “In the Media’s effort to destroy the Presiden...
# 3   Howard Schultz doesn’t have the “guts” to run ...
# 4   Numerous states introducing Bible Literacy cla...
# 5   Tariffs on the “dumping” of Steel in the Unite...
# 6   After all that I have done for the Military, o...
# 7   Never thought I’d say this but I think @johnro...
# 8   BUILD A WALL &amp; CRIME WILL FALL! https://t....
# 9   #HolocaustMemorialDay\nhttps://t.co/zBQjfUOdtj...
# 10  RT @GOP: “300 people are dying from heroin ove...
# 11  RT @KenPaxtonTX: VOTER FRAUD ALERT: The @TXsec...
# 12  Thank you to Brit. This is a very big deal in ...
# 13  RT @ChatByCC: Strong people stand up for thems...
# 14  Jens Stoltenberg, NATO Secretary General, just...
# 15  We are not even into February and the cost of ...
# 16  58,000 non-citizens voted in Texas, with 95,00...
# 17                                        WITCH HUNT!
# 18  ....about all of the one sided Fake Media cove...
# 19  CBS reports that in the Roger Stone indictment...

# %%
data['Date'] = [x.created_at for x in tweets]
data
# Out:
#                                                 Tweets                Date
# 0    How does Da Nang Dick (Blumenthal) serve on th... 2019-01-29 02:46:02
# 1    In the beautiful Midwest, windchill temperatur... 2019-01-29 02:28:49
# 2    “In the Media’s effort to destroy the Presiden... 2019-01-28 13:50:11
# 3    Howard Schultz doesn’t have the “guts” to run ... 2019-01-28 13:41:52
# 4    Numerous states introducing Bible Literacy cla... 2019-01-28 13:21:15
# 5    Tariffs on the “dumping” of Steel in the Unite... 2019-01-28 13:16:32
# 6    After all that I have done for the Military, o... 2019-01-28 01:09:49
# 7    Never thought I’d say this but I think @johnro... 2019-01-28 01:08:09
# 8    BUILD A WALL &amp; CRIME WILL FALL! https://t.... 2019-01-27 18:22:55
# 9    #HolocaustMemorialDay\nhttps://t.co/zBQjfUOdtj... 2019-01-27 18:04:38
# 10   RT @GOP: “300 people are dying from heroin ove... 2019-01-27 15:30:50
# 11   RT @KenPaxtonTX: VOTER FRAUD ALERT: The @TXsec... 2019-01-27 15:28:22
# 12   Thank you to Brit. This is a very big deal in ... 2019-01-27 15:27:29
# 13   RT @ChatByCC: Strong people stand up for thems... 2019-01-27 15:20:27
# 14   Jens Stoltenberg, NATO Secretary General, just... 2019-01-27 15:11:55
# 15   We are not even into February and the cost of ... 2019-01-27 13:44:39
# 16   58,000 non-citizens voted in Texas, with 95,00... 2019-01-27 13:22:19
# 17                                         WITCH HUNT! 2019-01-27 01:51:57
# 18   ....about all of the one sided Fake Media cove... 2019-01-27 01:49:53
# 19   CBS reports that in the Roger Stone indictment... 2019-01-27 01:39:07
# 198  Best line in the Elizabeth Warren beer catastr... 2019-01-14 03:03:03
# 199  If Elizabeth Warren, often referred to by me a... 2019-01-14 02:52:59
#
# [200 rows x 2 columns]

# %%
data['len']  = [len(x.text) for x in tweets]  # number of characters in a tweet (think length)
data['ID']   = [x.id for x in tweets]
data['Source'] = [x.source for x in tweets]
data['Likes']  = [x.favorite_count for x in tweets] # favorite_count
data['RTs']    =  [x.retweet_count for x in tweets]  # retweet count

# %%
display(data.head(10))
# Out:
#                                               Tweets                Date  len  \
# 0  How does Da Nang Dick (Blumenthal) serve on th... 2019-01-29 02:46:02  140
# 1  In the beautiful Midwest, windchill temperatur... 2019-01-29 02:28:49  140
# 2  “In the Media’s effort to destroy the Presiden... 2019-01-28 13:50:11  140
# 3  Howard Schultz doesn’t have the “guts” to run ... 2019-01-28 13:41:52  139
# 4  Numerous states introducing Bible Literacy cla... 2019-01-28 13:21:15  138
# 5  Tariffs on the “dumping” of Steel in the Unite... 2019-01-28 13:16:32  140
# 6  After all that I have done for the Military, o... 2019-01-28 01:09:49  143
# 7  Never thought I’d say this but I think @johnro... 2019-01-28 01:08:09  140
# 8  BUILD A WALL &amp; CRIME WILL FALL! https://t.... 2019-01-27 18:22:55   59
# 9  #HolocaustMemorialDay\nhttps://t.co/zBQjfUOdtj... 2019-01-27 18:04:38   69
#
#                     ID              Source   Likes    RTs
# 0  1090078588748087296  Twitter for iPhone   76729  19674
# 1  1090074254010404864  Twitter for iPhone   94768  23625
# 2  1089883338758914048  Twitter for iPhone   97760  22273
# 3  1089881244312178688  Twitter for iPhone   92327  19618
# 4  1089876055224184833  Twitter for iPhone  199751  43301
# 5  1089874871247687683  Twitter for iPhone  106704  24345
# 6  1089691985164800001  Twitter for iPhone  211572  45655
# 7  1089691564283183105  Twitter for iPhone   83921  18532
# 8  1089589587456991233  Twitter for iPhone  114080  32993
# 9  1089584983415627776  Twitter for iPhone   63256  14727

# %%
import numpy as np
rt_max = data['RTs'].max()
rt_tweet = data[data['RTs'] == rt_max]
# Max RTs:
print("The tweet with more retweets is: \n{}".format(np.array(rt_tweet['Tweets'])[0]))
print("Number of retweets: {}".format(rt_max))
print("{} characters.\n".format(np.array(rt_tweet['len'])[0]))
# Out:
# The tweet with more retweets is:
# The citizens of Venezuela have suffered for too long at the hands of the illegitimate Maduro regime. Today, I have… https://t.co/6pcpLqVzaQ
# Number of retweets: 81390
# 139 characters.

# %%
# We can create a time series of tweet length like this
tlen = pd.Series(data=data['len'].values, index=data['Date'])

# %%
# ...and plot it against time
tlen.plot(figsize=(16,4), color='r')

# %%
# Plot a likes vs retweets visualization, by getting the time series 
# for favourites and of retweets
tfav = pd.Series(data=data['Likes'].values, index=data['Date'])
tret = pd.Series(data=data['RTs'].values, index=data['Date'])

tfav.plot(figsize=(16,4), label="Likes", legend=True)
tret.plot(figsize=(16,4), label="Retweets", legend=True)
